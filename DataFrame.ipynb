# %%
import pandas as pd 
import numpy as np

# %%
pd.Series( [str , print] )
# Out:
# 0                <class 'str'>
# 1    <built-in function print>
# dtype: object

# %%
df1 = pd.DataFrame(0 , index= ['X' , 'Y' , 'Z'] , columns= ['C1' , 'C2'])

# %%
df1
# Out:
#    C1  C2
# X   0   0
# Y   0   0
# Z   0   0

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(pd)
# Out:
# module

# %%
type(np)
# Out:
# module

# %%
df1.reset_index()
# Out:
#   index  C1  C2
# 0     X   0   0
# 1     Y   0   0
# 2     Z   0   0

# %%
np.random.seed(1)

# %%
df = pd.DataFrame(np.random.randn(3,3) , index= ['X' , 'Y' , 'Z'] , columns= ['C1' , 'C2' , 'C3'])

# %%
df
# Out:
#          C1        C2        C3
# X  1.624345 -0.611756 -0.528172
# Y -1.072969  0.865408 -2.301539
# Z  1.744812 -0.761207  0.319039

# %%
df['C1']
# Out:
# X    1.624345
# Y   -1.072969
# Z    1.744812
# Name: C1, dtype: float64

# %%
df[ ['C1' , 'C2'] ]
# Out:
#          C1        C2
# X  1.624345 -0.611756
# Y -1.072969  0.865408
# Z  1.744812 -0.761207

# %%
df['C4'] = df['C1'] + df['C2']

# %%
df
# Out:
#          C1        C2        C3        C4
# X  1.624345 -0.611756 -0.528172  1.012589
# Y -1.072969  0.865408 -2.301539 -0.207561
# Z  1.744812 -0.761207  0.319039  0.983605

# %%
df.loc['Y']
# Out:
# C1   -1.072969
# C2    0.865408
# C3   -2.301539
# C4   -0.207561
# Name: Y, dtype: float64

# %%
df.iloc[2] # get any row or set of rows with index
# Out:
# C1    1.744812
# C2   -0.761207
# C3    0.319039
# C4    0.983605
# Name: Z, dtype: float64

# %%
df.iloc[ 0 : ]
# Out:
#          C1        C2        C3        C4
# X  1.624345 -0.611756 -0.528172  1.012589
# Y -1.072969  0.865408 -2.301539 -0.207561
# Z  1.744812 -0.761207  0.319039  0.983605

# %%
df.loc[['X' , 'Y']]
# Out:
#          C1        C2        C3        C4
# X  1.624345 -0.611756 -0.528172  1.012589
# Y -1.072969  0.865408 -2.301539 -0.207561

# %%
df.loc[['X' , 'Y'] , ['C1' , 'C2'] ]
# Out:
#          C1        C2
# X  1.624345 -0.611756
# Y -1.072969  0.865408

# %%
df.iloc[0 : 2 , 0 : 2] # [0 : 2 -- > form r1 to r2  , 0 : 2 -- >form C1 to C2 ]
# Out:
#          C1        C2
# X  1.624345 -0.611756
# Y -1.072969  0.865408

# %%
# to get any cell in ur DataFrame

df.loc['X' , 'C1']
# Out:
# 1.6243453636632417

# %%
df.drop('C4' ,axis =1)
# Out:
#          C1        C2        C3
# X  1.624345 -0.611756 -0.528172
# Y -1.072969  0.865408 -2.301539
# Z  1.744812 -0.761207  0.319039

# %%
df
# Out:
#          C1        C2        C3        C4
# X  1.624345 -0.611756 -0.528172  1.012589
# Y -1.072969  0.865408 -2.301539 -0.207561
# Z  1.744812 -0.761207  0.319039  0.983605

# %%
df.drop('C4' ,axis =1 , inplace=True) # inplace=True to make the change commitment

# %%
df
# Out:
#          C1        C2        C3
# X  1.624345 -0.611756 -0.528172
# Y -1.072969  0.865408 -2.301539
# Z  1.744812 -0.761207  0.319039

# %%
df.drop('X' ,axis = 0 , inplace=True)

# %%
df
# Out:
#          C1        C2        C3
# Y -1.072969  0.865408 -2.301539
# Z  1.744812 -0.761207  0.319039

# %%
# finally thank you
